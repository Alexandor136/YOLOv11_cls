# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11l-obb.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="C:\Projects\A600\YOLOv11\datasets", epochs=20, plots=True, save=True, shear=15)

# %%
import os
from ultralytics import YOLO

model = YOLO("C:\Projects\A600\YOLOv11_cls/runs\classify/train3/weights/best.pt")  # load a custom model

# Путь к папке с изображениями
folder_path = "new_data/new_afro"
# Перебираем все файлы в указанной папке
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    print(filename)
    
    results = model(f"{folder_path}/{filename}")  # predict on an image
    print(results)
    results[0].show()

    print("Перебор изображений завершен!")
# Out:
# screenshot_1733297403.jpg
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Sablin-aa.BIRYUSA\AppData\Local\Temp\ipykernel_7768\3318523163.py:4: SyntaxWarning: invalid escape sequence '\P'
#   model = YOLO("C:\Projects\A600\YOLOv11_cls/runs\classify/train3/weights/best.pt")  # load a custom model
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297403.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 43.0ms
# Speed: 13.0ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 42, 115,  93],
#         [ 52, 134, 111],
#         [ 34, 120,  96]],
#
#        [[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 41, 114,  92],
#         [ 50, 132, 109],
#         [ 35, 121,  97]],
#
#        [[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 38, 111,  89],
#         [ 46, 128, 105],
#         [ 37, 123,  99]],
#
#        ...,
#
#        [[ 13,  62,  54],
#         [ 24,  73,  65],
#         [ 42,  86,  79],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 20,  64,  57],
#         [ 26,  70,  63],
#         [ 40,  81,  74],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 25,  67,  60],
#         [ 28,  70,  63],
#         [ 39,  77,  71],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297403.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 13.001203536987305, 'inference': 42.996883392333984, 'postprocess': 0.0}]
# Перебор изображений завершен!
# screenshot_1733297483.jpg
#
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297483.jpg: 224x224 109 1.00, 108 0.00, 122 0.00, 124 0.00, 112 0.00, 49.0ms
# Speed: 29.0ms preprocess, 49.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 52, 125, 103],
#         [ 52, 134, 111],
#         [ 34, 120,  96]],
#
#        [[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 43, 116,  94],
#         [ 43, 125, 102],
#         [ 29, 115,  91]],
#
#        [[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 34, 107,  85],
#         [ 34, 116,  93],
#         [ 27, 113,  89]],
#
#        ...,
#
#        [[ 15,  64,  56],
#         [ 29,  78,  70],
#         [ 48,  92,  85],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 16,  60,  53],
#         [ 28,  72,  65],
#         [ 45,  86,  79],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 16,  58,  51],
#         [ 27,  69,  62],
#         [ 42,  80,  74],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297483.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 28.99336814880371, 'inference': 48.995018005371094, 'postprocess': 0.0}]
# Перебор изображений завершен!
# screenshot_1733297504.jpg
#
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297504.jpg: 224x224 109 0.99, 108 0.01, 122 0.00, 112 0.00, 8 0.00, 50.0ms
# Speed: 13.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 22,  17,  18],
#         [ 22,  17,  18],
#         [ 20,  15,  16],
#         ...,
#         [ 31, 104,  82],
#         [ 40, 122,  99],
#         [ 34, 120,  96]],
#
#        [[ 23,  18,  19],
#         [ 22,  17,  18],
#         [ 21,  16,  17],
#         ...,
#         [ 30, 103,  81],
#         [ 38, 120,  97],
#         [ 33, 119,  95]],
#
#        [[ 22,  20,  20],
#         [ 22,  20,  20],
#         [ 20,  18,  18],
#         ...,
#         [ 29, 102,  80],
#         [ 34, 116,  93],
#         [ 33, 119,  95]],
#
#        ...,
#
#        [[  5,  54,  46],
#         [ 19,  68,  60],
#         [ 38,  82,  75],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 10,  54,  47],
#         [ 22,  66,  59],
#         [ 37,  78,  71],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 13,  55,  48],
#         [ 24,  66,  59],
#         [ 37,  75,  69],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297504.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 12.962579727172852, 'inference': 49.99542236328125, 'postprocess': 0.0}]
# Перебор изображений завершен!
# screenshot_1733297858.jpg
#
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297858.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 50.0ms
# Speed: 13.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 38, 111,  89],
#         [ 47, 129, 106],
#         [ 29, 115,  91]],
#
#        [[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 36, 109,  87],
#         [ 45, 127, 104],
#         [ 30, 116,  92]],
#
#        [[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 33, 106,  84],
#         [ 42, 124, 101],
#         [ 32, 118,  94]],
#
#        ...,
#
#        [[ 22,  58,  52],
#         [ 37,  73,  67],
#         [ 54,  88,  82],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 18,  54,  48],
#         [ 32,  68,  62],
#         [ 48,  82,  76],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 16,  52,  46],
#         [ 29,  65,  59],
#         [ 44,  78,  72],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297858.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 12.998819351196289, 'inference': 49.993038177490234, 'postprocess': 0.0}]
# Перебор изображений завершен!
# screenshot_1733298184.jpg
#
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733298184.jpg: 224x224 109 1.00, 108 0.00, 122 0.00, 112 0.00, 124 0.00, 42.0ms
# Speed: 12.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 54, 127, 105],
#         [ 53, 135, 112],
#         [ 23, 109,  85]],
#
#        [[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 50, 123, 101],
#         [ 50, 132, 109],
#         [ 24, 110,  86]],
#
#        [[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 43, 116,  94],
#         [ 45, 127, 104],
#         [ 27, 113,  89]],
#
#        ...,
#
#        [[  0,  49,  41],
#         [ 15,  64,  56],
#         [ 36,  80,  73],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[  5,  49,  42],
#         [ 18,  62,  55],
#         [ 35,  76,  69],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[  9,  51,  44],
#         [ 20,  62,  55],
#         [ 34,  72,  66],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733298184.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 11.976003646850586, 'inference': 41.99528694152832, 'postprocess': 0.0}]
# Перебор изображений завершен!
# screenshot_1733298570.jpg
#
# image 1/1 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733298570.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 43.0ms
# Speed: 13.0ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 42, 111, 100],
#         [ 36, 115, 102],
#         [ 20, 102,  89]],
#
#        [[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 40, 109,  98],
#         [ 35, 114, 101],
#         [ 21, 103,  90]],
#
#        [[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 37, 106,  95],
#         [ 34, 113, 100],
#         [ 23, 105,  92]],
#
#        ...,
#
#        [[ 23,  72,  64],
#         [ 38,  87,  79],
#         [ 59, 103,  96],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 16,  60,  53],
#         [ 32,  76,  69],
#         [ 52,  93,  86],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 12,  54,  47],
#         [ 27,  69,  62],
#         [ 47,  85,  79],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733298570.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 12.956619262695312, 'inference': 43.00093650817871, 'postprocess': 0.0}]
# Перебор изображений завершен!

# %%
import os
from ultralytics import YOLO

model = YOLO("C:\Projects\A600\YOLOv11_cls/runs\classify/train3/weights/best.pt")  # load a custom model

results = model("new_data/new_afro")  # predict on an image
print(results)

results[0].show()
results.xyxy[0]


print("Перебор изображений завершен!")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Sablin-aa.BIRYUSA\AppData\Local\Temp\ipykernel_7768\1576099285.py:4: SyntaxWarning: invalid escape sequence '\P'
#   model = YOLO("C:\Projects\A600\YOLOv11_cls/runs\classify/train3/weights/best.pt")  # load a custom model
# image 1/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297403.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 36.0ms
# image 2/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297483.jpg: 224x224 109 1.00, 108 0.00, 122 0.00, 124 0.00, 112 0.00, 36.0ms
# image 3/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297504.jpg: 224x224 109 0.99, 108 0.01, 122 0.00, 112 0.00, 8 0.00, 38.0ms
# image 4/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733297858.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 41.0ms
# image 5/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733298184.jpg: 224x224 109 1.00, 108 0.00, 122 0.00, 112 0.00, 124 0.00, 37.0ms
# image 6/6 c:\Projects\A600\YOLOv11_cls\new_data\new_afro\screenshot_1733298570.jpg: 224x224 109 0.99, 108 0.01, 112 0.00, 122 0.00, 8 0.00, 38.0ms
# Speed: 12.7ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 42, 115,  93],
#         [ 52, 134, 111],
#         [ 34, 120,  96]],
#
#        [[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 41, 114,  92],
#         [ 50, 132, 109],
#         [ 35, 121,  97]],
#
#        [[ 33,  26,  17],
#         [ 33,  26,  17],
#         [ 33,  26,  17],
#         ...,
#         [ 38, 111,  89],
#         [ 46, 128, 105],
#         [ 37, 123,  99]],
#
#        ...,
#
#        [[ 13,  62,  54],
#         [ 24,  73,  65],
#         [ 42,  86,  79],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 20,  64,  57],
#         [ 26,  70,  63],
#         [ 40,  81,  74],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 25,  67,  60],
#         [ 28,  70,  63],
#         [ 39,  77,  71],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297403.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 13.001441955566406, 'inference': 35.993099212646484, 'postprocess': 0.0}, ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 52, 125, 103],
#         [ 52, 134, 111],
#         [ 34, 120,  96]],
#
#        [[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 43, 116,  94],
#         [ 43, 125, 102],
#         [ 29, 115,  91]],
#
#        [[148, 169, 196],
#         [146, 167, 194],
#         [144, 165, 192],
#         ...,
#         [ 34, 107,  85],
#         [ 34, 116,  93],
#         [ 27, 113,  89]],
#
#        ...,
#
#        [[ 15,  64,  56],
#         [ 29,  78,  70],
#         [ 48,  92,  85],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 16,  60,  53],
#         [ 28,  72,  65],
#         [ 45,  86,  79],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]],
#
#        [[ 16,  58,  51],
#         [ 27,  69,  62],
#         [ 42,  80,  74],
#         ...,
#         [ 38, 130,  95],
#         [ 38, 130,  95],
#         [ 38, 130,  95]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297483.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 14.006853103637695, 'inference': 35.98809242248535, 'postprocess': 0.0}, ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 22,  17,  18],
#         [ 22,  17,  18],
#         [ 20,  15,  16],
#         ...,
#         [ 31, 104,  82],
#         [ 40, 122,  99],
#         [ 34, 120,  96]],
#
#        [[ 23,  18,  19],
#         [ 22,  17,  18],
#         [ 21,  16,  17],
#         ...,
#         [ 30, 103,  81],
#         [ 38, 120,  97],
#         [ 33, 119,  95]],
#
#        [[ 22,  20,  20],
#         [ 22,  20,  20],
#         [ 20,  18,  18],
#         ...,
#         [ 29, 102,  80],
#         [ 34, 116,  93],
#         [ 33, 119,  95]],
#
#        ...,
#
#        [[  5,  54,  46],
#         [ 19,  68,  60],
#         [ 38,  82,  75],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 10,  54,  47],
#         [ 22,  66,  59],
#         [ 37,  78,  71],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 13,  55,  48],
#         [ 24,  66,  59],
#         [ 37,  75,  69],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297504.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 13.002395629882812, 'inference': 37.99104690551758, 'postprocess': 0.0}, ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 38, 111,  89],
#         [ 47, 129, 106],
#         [ 29, 115,  91]],
#
#        [[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 36, 109,  87],
#         [ 45, 127, 104],
#         [ 30, 116,  92]],
#
#        [[ 19,  19,  19],
#         [ 19,  19,  19],
#         [ 19,  19,  19],
#         ...,
#         [ 33, 106,  84],
#         [ 42, 124, 101],
#         [ 32, 118,  94]],
#
#        ...,
#
#        [[ 22,  58,  52],
#         [ 37,  73,  67],
#         [ 54,  88,  82],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 18,  54,  48],
#         [ 32,  68,  62],
#         [ 48,  82,  76],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 16,  52,  46],
#         [ 29,  65,  59],
#         [ 44,  78,  72],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733297858.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 12.998104095458984, 'inference': 40.993690490722656, 'postprocess': 0.0}, ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 54, 127, 105],
#         [ 53, 135, 112],
#         [ 23, 109,  85]],
#
#        [[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 50, 123, 101],
#         [ 50, 132, 109],
#         [ 24, 110,  86]],
#
#        [[ 30,  59,  64],
#         [ 30,  59,  64],
#         [ 30,  59,  64],
#         ...,
#         [ 43, 116,  94],
#         [ 45, 127, 104],
#         [ 27, 113,  89]],
#
#        ...,
#
#        [[  0,  49,  41],
#         [ 15,  64,  56],
#         [ 36,  80,  73],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[  5,  49,  42],
#         [ 18,  62,  55],
#         [ 35,  76,  69],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[  9,  51,  44],
#         [ 20,  62,  55],
#         [ 34,  72,  66],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733298184.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 10.998249053955078, 'inference': 36.994218826293945, 'postprocess': 1.001596450805664}, ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: '10', 1: '106', 2: '108', 3: '109', 4: '110', 5: '111', 6: '112', 7: '114', 8: '116', 9: '118', 10: '120', 11: '122', 12: '124', 13: '14', 14: '151', 15: '152', 16: '153', 17: '290', 18: '6', 19: '8'}
# obb: None
# orig_img: array([[[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 42, 111, 100],
#         [ 36, 115, 102],
#         [ 20, 102,  89]],
#
#        [[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 40, 109,  98],
#         [ 35, 114, 101],
#         [ 21, 103,  90]],
#
#        [[ 36,  65,  70],
#         [ 39,  68,  73],
#         [ 43,  72,  77],
#         ...,
#         [ 37, 106,  95],
#         [ 34, 113, 100],
#         [ 23, 105,  92]],
#
#        ...,
#
#        [[ 23,  72,  64],
#         [ 38,  87,  79],
#         [ 59, 103,  96],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 16,  60,  53],
#         [ 32,  76,  69],
#         [ 52,  93,  86],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]],
#
#        [[ 12,  54,  47],
#         [ 27,  69,  62],
#         [ 47,  85,  79],
#         ...,
#         [ 33, 125,  90],
#         [ 33, 125,  90],
#         [ 33, 125,  90]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: 'c:\\Projects\\A600\\YOLOv11_cls\\new_data\\new_afro\\screenshot_1733298570.jpg'
# probs: ultralytics.engine.results.Probs object
# save_dir: 'runs\\classify\\predict'
# speed: {'preprocess': 11.99960708618164, 'inference': 37.99629211425781, 'postprocess': 0.0}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 10
#       7 print(results)
#       9 results[0].show()
# ---> 10 results.xyxy[0]
#      13 print("Перебор изображений завершен!")
#
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
import cv2

import os
from ultralytics import YOLO

model = YOLO("C:/A600/YOLOv11/runs/classify/train3/weights/best.pt")  # load a custom model

# Замените 'http://username:password@ip_address:port/video' на URL вашей IP-камеры
url = 'http://192.168.3.114/ISAPI/Streaming/channels/101/picture?snapShotImageType=JPEG'

# Открываем видеопоток
cap = cv2.VideoCapture(url)

if not cap.isOpened():
    print("Ошибка: Не удалось подключиться к камере.")
    exit()

while True:
    # Читаем кадр из потока
    ret, frame = cap.read()
    
    if not ret:
        print("Ошибка: Не удалось получить кадр.")
        break

    # Обработка кадра 
    results = model("frame")  # predict on an image

    # Отображаем обработанный кадр
    cv2.imshow('Gray Frame', results)

    # Выход из цикла при нажатии клавиши 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Освобождаем ресурсы
cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("C:/A600/YOLOv11/runs/classify/train3/weights/best.pt")  # pretrained YOLO11n model

results = model.predict("C:\A600\YOLOv11/new_data\screenshot_1733819867.jpg", save=True, conf=1, max_det = 1, save_txt = True, save_conf = True)
results[0].show()
